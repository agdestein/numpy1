# %% [markdown]
# # Using Numpy version 1
#
# Let's import numpy.

# %%
import numpy as np

# %% [markdown]
# The following function should not be defined in numpy v2, but in our virtual environment we have numpy v1.

# %%
np.product
# Out:
# <function product at 0x7cbe85103bf0>

# %%
import matplotlib.pyplot as plt

plt.plot(np.random.randn(1000).cumsum())
